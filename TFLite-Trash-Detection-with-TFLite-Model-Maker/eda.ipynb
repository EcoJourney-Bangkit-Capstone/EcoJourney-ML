# %%
import pandas as pd

# %%
path = 'data/'

df_train = pd.read_csv(path + 'train_labels.csv')
df_test = pd.read_csv(path + 'test_labels.csv')

# %%
df = pd.concat([df_train, df_test], axis=0)
df
# Out:
#                                               filename  width  height  \
# 0    000000_jpg.rf.0c6cbe31c8cd3a8fff7e59cd8543d2ef...    640     640
# 1    000000_jpg.rf.0c6cbe31c8cd3a8fff7e59cd8543d2ef...    640     640
# 2    000000_jpg.rf.0c6cbe31c8cd3a8fff7e59cd8543d2ef...    640     640
# 3    000000_jpg.rf.20685588e69603a7984f8b91dd079b24...    640     640
# 4    000000_jpg.rf.20685588e69603a7984f8b91dd079b24...    640     640
# ..                                                 ...    ...     ...
# 565  IMG_5055_JPG_jpg.rf.21ff1e516973731914a3020ef8...    640     640
# 566  IMG_5060_JPG_jpg.rf.b63687ede7d10340aedf17bf0e...    640     640
# 567  IMG_5060_JPG_jpg.rf.b63687ede7d10340aedf17bf0e...    640     640
# 568  IMG_5060_JPG_jpg.rf.b63687ede7d10340aedf17bf0e...    640     640
# 569  IMG_5060_JPG_jpg.rf.b63687ede7d10340aedf17bf0e...    640     640
#
#        class  xmin  ymin  xmax  ymax
# 0      Trash    29   518    38   531
# 1      Paper   297   332   310   349
# 2      Paper   322   244   362   278
# 3    Plastic   393   310   423   356
# 4      Paper   278   449   294   471
# ..       ...   ...   ...   ...   ...
# 565    Metal   359   354   371   368
# 566    Trash   265   402   344   476
# 567    Trash   290   197   296   208
# 568    Trash   502   131   515   135
# 569    Trash   575   112   593   120
#
# [9774 rows x 8 columns]

# %%
df['class'].value_counts()
# Out:
# class
# Plastic            4472
# Trash              2685
# Metal              1134
# Cardboard           507
# Paper               506
# Glass               433
# Shoes                13
# Biological           11
# Plastic glooves       9
# Battery               4
# Name: count, dtype: int64
